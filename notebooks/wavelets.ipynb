# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sympy as sp

# %%
import pywavelet as pwv

# %%
wave = pwv.wavelet.WaveletMorlet()

# %%
w_0 = sp.Symbol('\omega_0')
eta = sp.Symbol('\eta')
eta
# Out:
# \eta

# %%
psi_0 = sp.pi ** (-1/4) * sp.exp(complex(imag=1) * w_0 * eta) * sp.exp(-eta**2 / 2)

# %%
psi_0
# Out:
# pi**(-0.25)*exp(-\eta**2/2)*exp(1.0*I*\eta*\omega_0)

# %%
nino3['del_T'].values
# Out:
# array([-0.15, -0.3 , -0.14, -0.41, -0.46, -0.66, -0.5 , -0.8 , -0.95,
#        -0.72, -0.31, -0.71, -1.04, -0.77, -0.86, -0.84, -0.41, -0.49,
#        -0.48, -0.72, -1.21, -0.8 ,  0.16,  0.46,  0.4 ,  1.  ,  2.17,
#         2.5 ,  2.34,  0.8 ,  0.14, -0.06, -0.34, -0.71, -0.34, -0.73,
#        -0.48, -0.11,  0.22,  0.51,  0.51,  0.25, -0.1 , -0.33, -0.42,
#        -0.23, -0.53, -0.44, -0.3 ,  0.15,  0.09,  0.19, -0.06,  0.25,
#         0.3 ,  0.81,  0.26,  0.1 ,  0.34,  1.01, -0.31, -0.9 , -0.73,
#        -0.92, -0.73, -0.31, -0.03,  0.12,  0.37,  0.82,  1.22,  1.83,
#         1.6 ,  0.34, -0.72, -0.87, -0.85, -0.4 , -0.39, -0.65,  0.07,
#         0.67,  0.39,  0.03, -0.17, -0.76, -0.87, -1.36, -1.1 , -0.99,
#        -0.78, -0.93, -0.87, -0.44, -0.34, -0.5 , -0.39, -0.04,  0.42,
#         0.62,  0.17,  0.23,  1.03,  1.54,  1.09,  0.01,  0.12, -0.27,
#        -0.47, -0.41, -0.37, -0.36, -0.39,  0.43,  1.05,  1.58,  1.25,
# ...
