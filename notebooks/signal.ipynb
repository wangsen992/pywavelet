# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

# %%
import pywavelet as pwv

# %%
pwv.signal.PandasSignal
# Out:
# <module 'pywavelet.signal' from '/Users/senwang/Workspace/development/pywavelet/src/pywavelet/signal/__init__.py'>

# %%
nino3 = pd.read_csv("../data/nino3.csv",index_col='time')['del_T']

# %%
pd_signal = pwv.signal.PandasSignal(data=nino3)

# %%
ax = pd_signal.plot(figsize=(12,5))
ax.grid(True)
